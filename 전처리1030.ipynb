# %% [markdown]
# 1단계 전처리

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from tqdm import tqdm
import sys

def calculate_hi_from_csv(file_path):
    """
    단일 CSV 파일에서 수평 진동 신호(5번째 열)를 읽어
    Kurtosis와 RMS를 계산합니다.
    """
    try:
        # 파일 헤더가 없으므로 header=None
        # 5번째 열 (인덱스 4)의 데이터만 읽어옵니다.
        data = pd.read_csv(file_path, header=None).iloc[:, 4]
        
        # Kurtosis 계산 (pandas 기본 함수 사용)
        kurt = data.kurt()
        
        # RMS 계산 (Numpy 사용)
        rms = np.sqrt(np.mean(data**2))
        
        return kurt, rms
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        return None, None

# --- 1. 경로 설정 ---
# 스크립트를 실행하는 현재 폴더를 기준으로 합니다.
BASE_PATH = Path(".") 
LEARNING_SET_PATH = BASE_PATH / "Learning_set"
FULL_TEST_SET_PATH = BASE_PATH / "Full_Test_Set" # (Ground Truth RUL 계산을 위해 Full_Test_Set 사용)

# 전처리된 HI 데이터를 저장할 새 폴더 (현재 폴더 하위에 생성)
OUTPUT_PATH = BASE_PATH / "HI_preprocessed"
OUTPUT_PATH.mkdir(parents=True, exist_ok=True) # 폴더가 없으면 생성

# --- 2. 대상 베어링 정의 (Condition 1) ---
learning_bearings = ["Bearing1_1", "Bearing1_2"]
test_bearings = ["Bearing1_3", "Bearing1_4", "Bearing1_5", "Bearing1_6", "Bearing1_7"]
all_bearings = learning_bearings + test_bearings

print(f"Starting HI extraction for {len(all_bearings)} bearings...")
print(f"Base path is: {BASE_PATH.resolve()}")
print(f"Data will be saved in: {OUTPUT_PATH.resolve()}")
print("-" * 30)

# --- 3. 메인 처리 루프 ---
for bearing_name in tqdm(all_bearings, desc="Overall Progress"):
    
    # 베어링이 학습셋에 있는지 테스트셋에 있는지에 따라 경로 설정
    if bearing_name in learning_bearings:
        bearing_path = LEARNING_SET_PATH / bearing_name
    else:
        bearing_path = FULL_TEST_SET_PATH / bearing_name

    if not bearing_path.exists():
        print(f"Warning: Directory not found for {bearing_name} at {bearing_path.resolve()}. Skipping.")
        continue

    # 'acc_*.csv' 파일 목록을 가져오고, 이름순으로 정렬 (필수!)
    file_list = sorted(list(bearing_path.glob("acc_*.csv")))
    
    if not file_list:
        print(f"Warning: No 'acc_*.csv' files found in {bearing_path}. Skipping.")
        continue

    hi_data = [] # (Kurtosis, RMS) 결과를 저장할 리스트

    # 개별 파일 처리 (tqdm으로 진행률 표시)
    for file_path in tqdm(file_list, desc=f"Processing {bearing_name}", leave=False):
        kurt, rms = calculate_hi_from_csv(file_path)
        if kurt is not None:
            hi_data.append({"kurtosis": kurt, "rms": rms})

    # --- 4. 결과 저장 ---
    if hi_data:
        # 리스트를 Pandas DataFrame으로 변환
        hi_df = pd.DataFrame(hi_data)
        
        # 각 스냅샷(파일)의 순서를 인덱스로 하여 CSV로 저장
        save_file_path = OUTPUT_PATH / f"{bearing_name}_hi.csv"
        hi_df.to_csv(save_file_path, index_label="snapshot_index")

print("-" * 30)
print("Step 1: HI (Kurtosis, RMS) extraction complete!")
print(f"Check the results in {OUTPUT_PATH.resolve()}")
# Out:
# Starting HI extraction for 7 bearings...
# Base path is: /home/work/RUL_AL/Pronostia dataset
# Data will be saved in: /home/work/RUL_AL/Pronostia dataset/HI_preprocessed
# ------------------------------
# Overall Progress:   0% 0/7 [00:00<?, ?it/s]
# cessing Bearing1_1:   0% 0/2803 [00:00<?, ?it/s]
# cessing Bearing1_1:   1% 35/2803 [00:00<00:08, 341.14it/s]
# cessing Bearing1_1:   2% 70/2803 [00:00<00:08, 326.02it/s]
# cessing Bearing1_1:   4% 103/2803 [00:00<00:08, 324.46it/s]
# cessing Bearing1_1:   5% 137/2803 [00:00<00:08, 329.15it/s]
# cessing Bearing1_1:   6% 170/2803 [00:00<00:08, 327.75it/s]
# cessing Bearing1_1:   7% 204/2803 [00:00<00:07, 330.52it/s]
# cessing Bearing1_1:   8% 238/2803 [00:00<00:07, 327.86it/s]
# cessing Bearing1_1:  10% 271/2803 [00:00<00:07, 326.72it/s]
# cessing Bearing1_1:  11% 305/2803 [00:00<00:07, 326.70it/s]
# cessing Bearing1_1:  12% 339/2803 [00:01<00:07, 330.23it/s]
# cessing Bearing1_1:  13% 373/2803 [00:01<00:07, 330.41it/s]
# cessing Bearing1_1:  15% 407/2803 [00:01<00:07, 331.10it/s]
# cessing Bearing1_1:  16% 441/2803 [00:01<00:07, 329.92it/s]
# cessing Bearing1_1:  17% 474/2803 [00:01<00:07, 328.43it/s]
# cessing Bearing1_1:  18% 507/2803 [00:01<00:07, 327.85it/s]
# cessing Bearing1_1:  19% 540/2803 [00:01<00:06, 326.96it/s]
# cessing Bearing1_1:  20% 574/2803 [00:01<00:06, 330.32it/s]
# cessing Bearing1_1:  22% 608/2803 [00:01<00:06, 329.21it/s]
# cessing Bearing1_1:  23% 641/2803 [00:01<00:06, 318.23it/s]
# cessing Bearing1_1:  24% 673/2803 [00:02<00:06, 316.65it/s]
# cessing Bearing1_1:  25% 705/2803 [00:02<00:06, 301.92it/s]
# cessing Bearing1_1:  26% 737/2803 [00:02<00:06, 304.85it/s]
# cessing Bearing1_1:  28% 772/2803 [00:02<00:06, 311.71it/s]
# cessing Bearing1_1:  29% 805/2803 [00:02<00:06, 315.90it/s]
# cessing Bearing1_1:  30% 837/2803 [00:02<00:06, 299.71it/s]
# cessing Bearing1_1:  31% 868/2803 [00:02<00:06, 299.34it/s]
# cessing Bearing1_1:  32% 899/2803 [00:02<00:06, 296.22it/s]
# cessing Bearing1_1:  33% 929/2803 [00:02<00:06, 270.40it/s]
# cessing Bearing1_1:  34% 957/2803 [00:03<00:07, 255.64it/s]
# cessing Bearing1_1:  35% 985/2803 [00:03<00:06, 261.56it/s]
# cessing Bearing1_1:  36% 1013/2803 [00:03<00:06, 266.24it/s]
# cessing Bearing1_1:  37% 1041/2803 [00:03<00:06, 267.11it/s]
# cessing Bearing1_1:  38% 1069/2803 [00:03<00:06, 269.99it/s]
# cessing Bearing1_1:  39% 1098/2803 [00:03<00:06, 274.77it/s]
# cessing Bearing1_1:  40% 1126/2803 [00:03<00:06, 262.73it/s]
# cessing Bearing1_1:  41% 1153/2803 [00:03<00:07, 207.58it/s]
# cessing Bearing1_1:  42% 1182/2803 [00:04<00:07, 227.37it/s]
# cessing Bearing1_1:  43% 1210/2803 [00:04<00:06, 239.96it/s]
# cessing Bearing1_1:  44% 1237/2803 [00:04<00:06, 247.61it/s]
# cessing Bearing1_1:  45% 1265/2803 [00:04<00:06, 255.90it/s]
# cessing Bearing1_1:  46% 1294/2803 [00:04<00:05, 264.97it/s]
# cessing Bearing1_1:  47% 1322/2803 [00:04<00:05, 266.36it/s]
# cessing Bearing1_1:  48% 1350/2803 [00:04<00:05, 268.65it/s]
# cessing Bearing1_1:  49% 1379/2803 [00:04<00:05, 273.47it/s]
# cessing Bearing1_1:  50% 1407/2803 [00:04<00:05, 274.03it/s]
# cessing Bearing1_1:  51% 1435/2803 [00:04<00:04, 275.37it/s]
# cessing Bearing1_1:  52% 1463/2803 [00:05<00:04, 276.04it/s]
# cessing Bearing1_1:  53% 1491/2803 [00:05<00:04, 276.97it/s]
# cessing Bearing1_1:  54% 1519/2803 [00:05<00:04, 275.45it/s]
# cessing Bearing1_1:  55% 1552/2803 [00:05<00:04, 290.00it/s]
# cessing Bearing1_1:  57% 1584/2803 [00:05<00:04, 298.70it/s]
# cessing Bearing1_1:  58% 1620/2803 [00:05<00:03, 313.98it/s]
# cessing Bearing1_1:  59% 1654/2803 [00:05<00:03, 319.99it/s]
# cessing Bearing1_1:  60% 1689/2803 [00:05<00:03, 326.55it/s]
# cessing Bearing1_1:  61% 1722/2803 [00:05<00:03, 326.31it/s]
# cessing Bearing1_1:  63% 1755/2803 [00:05<00:03, 324.74it/s]
# cessing Bearing1_1:  64% 1788/2803 [00:06<00:03, 317.44it/s]
# cessing Bearing1_1:  65% 1822/2803 [00:06<00:03, 322.07it/s]
# cessing Bearing1_1:  66% 1855/2803 [00:06<00:02, 322.66it/s]
# cessing Bearing1_1:  67% 1889/2803 [00:06<00:02, 326.01it/s]
# cessing Bearing1_1:  69% 1923/2803 [00:06<00:02, 327.42it/s]
# cessing Bearing1_1:  70% 1956/2803 [00:06<00:02, 320.14it/s]
# cessing Bearing1_1:  71% 1989/2803 [00:06<00:02, 318.60it/s]
# cessing Bearing1_1:  72% 2021/2803 [00:06<00:02, 312.79it/s]
# cessing Bearing1_1:  73% 2055/2803 [00:06<00:02, 318.77it/s]
# cessing Bearing1_1:  75% 2089/2803 [00:06<00:02, 322.52it/s]
# cessing Bearing1_1:  76% 2123/2803 [00:07<00:02, 327.19it/s]
# cessing Bearing1_1:  77% 2156/2803 [00:07<00:01, 326.49it/s]
# cessing Bearing1_1:  78% 2189/2803 [00:07<00:01, 319.75it/s]
# cessing Bearing1_1:  79% 2222/2803 [00:07<00:01, 319.72it/s]
# cessing Bearing1_1:  80% 2255/2803 [00:07<00:01, 321.22it/s]
# cessing Bearing1_1:  82% 2288/2803 [00:07<00:01, 320.37it/s]
# cessing Bearing1_1:  83% 2321/2803 [00:07<00:01, 322.82it/s]
# cessing Bearing1_1:  84% 2355/2803 [00:07<00:01, 325.57it/s]
# cessing Bearing1_1:  85% 2390/2803 [00:07<00:01, 329.58it/s]
# cessing Bearing1_1:  86% 2423/2803 [00:08<00:01, 323.33it/s]
# cessing Bearing1_1:  88% 2457/2803 [00:08<00:01, 327.51it/s]
# cessing Bearing1_1:  89% 2490/2803 [00:08<00:00, 319.12it/s]
# cessing Bearing1_1:  90% 2522/2803 [00:08<00:00, 319.09it/s]
# cessing Bearing1_1:  91% 2556/2803 [00:08<00:00, 323.41it/s]
# cessing Bearing1_1:  92% 2589/2803 [00:08<00:00, 319.70it/s]
# cessing Bearing1_1:  94% 2622/2803 [00:08<00:00, 319.89it/s]
# cessing Bearing1_1:  95% 2655/2803 [00:08<00:00, 313.85it/s]
# cessing Bearing1_1:  96% 2687/2803 [00:08<00:00, 311.81it/s]
# cessing Bearing1_1:  97% 2719/2803 [00:08<00:00, 310.11it/s]
# cessing Bearing1_1:  98% 2751/2803 [00:09<00:00, 304.60it/s]
# cessing Bearing1_1:  99% 2782/2803 [00:09<00:00, 305.33it/s]
# Overall Progress:  14% 1/7 [00:09<00:55,  9.26s/it]
# cessing Bearing1_2:   0% 0/871 [00:00<?, ?it/s]
# cessing Bearing1_2:   3% 30/871 [00:00<00:02, 295.02it/s]
# cessing Bearing1_2:   7% 60/871 [00:00<00:05, 141.61it/s]
# cessing Bearing1_2:   9% 79/871 [00:00<00:05, 140.51it/s]
# cessing Bearing1_2:  13% 113/871 [00:00<00:03, 192.96it/s]
# cessing Bearing1_2:  17% 145/871 [00:00<00:03, 228.01it/s]
# cessing Bearing1_2:  20% 172/871 [00:00<00:03, 207.67it/s]
# cessing Bearing1_2:  23% 204/871 [00:00<00:02, 236.63it/s]
# cessing Bearing1_2:  27% 235/871 [00:01<00:02, 254.82it/s]
# cessing Bearing1_2:  31% 266/871 [00:01<00:02, 269.71it/s]
# cessing Bearing1_2:  34% 296/871 [00:01<00:02, 275.14it/s]
# cessing Bearing1_2:  37% 326/871 [00:01<00:01, 280.01it/s]
# cessing Bearing1_2:  41% 357/871 [00:01<00:01, 286.85it/s]
# cessing Bearing1_2:  45% 389/871 [00:01<00:01, 294.73it/s]
# cessing Bearing1_2:  48% 419/871 [00:01<00:01, 286.28it/s]
# cessing Bearing1_2:  52% 452/871 [00:01<00:01, 296.65it/s]
# cessing Bearing1_2:  56% 484/871 [00:01<00:01, 302.09it/s]
# cessing Bearing1_2:  59% 516/871 [00:02<00:01, 305.62it/s]
# cessing Bearing1_2:  63% 547/871 [00:02<00:01, 302.40it/s]
# cessing Bearing1_2:  66% 578/871 [00:02<00:00, 304.57it/s]
# cessing Bearing1_2:  70% 610/871 [00:02<00:00, 306.92it/s]
# cessing Bearing1_2:  74% 642/871 [00:02<00:00, 310.45it/s]
# cessing Bearing1_2:  77% 674/871 [00:02<00:00, 309.72it/s]
# cessing Bearing1_2:  81% 706/871 [00:02<00:00, 308.18it/s]
# cessing Bearing1_2:  85% 737/871 [00:02<00:00, 278.22it/s]
# cessing Bearing1_2:  88% 766/871 [00:02<00:00, 270.81it/s]
# cessing Bearing1_2:  92% 797/871 [00:02<00:00, 280.03it/s]
# cessing Bearing1_2:  95% 830/871 [00:03<00:00, 292.51it/s]
# cessing Bearing1_2:  99% 862/871 [00:03<00:00, 300.04it/s]
# Overall Progress:  29% 2/7 [00:12<00:29,  5.82s/it]
# cessing Bearing1_3:   0% 0/2375 [00:00<?, ?it/s]
# cessing Bearing1_3:   1% 34/2375 [00:00<00:07, 331.84it/s]
# cessing Bearing1_3:   3% 68/2375 [00:00<00:07, 324.43it/s]
# cessing Bearing1_3:   4% 103/2375 [00:00<00:06, 335.18it/s]
# cessing Bearing1_3:   6% 137/2375 [00:00<00:06, 330.19it/s]
# cessing Bearing1_3:   7% 172/2375 [00:00<00:06, 335.19it/s]
# cessing Bearing1_3:   9% 208/2375 [00:00<00:06, 340.71it/s]
# cessing Bearing1_3:  10% 243/2375 [00:00<00:06, 313.62it/s]
# cessing Bearing1_3:  12% 275/2375 [00:00<00:06, 310.60it/s]
# cessing Bearing1_3:  13% 308/2375 [00:00<00:06, 315.14it/s]
# cessing Bearing1_3:  14% 341/2375 [00:01<00:06, 317.64it/s]
# cessing Bearing1_3:  16% 375/2375 [00:01<00:06, 321.85it/s]
# cessing Bearing1_3:  17% 408/2375 [00:01<00:06, 318.57it/s]
# cessing Bearing1_3:  19% 440/2375 [00:01<00:06, 318.75it/s]
# cessing Bearing1_3:  20% 474/2375 [00:01<00:05, 323.66it/s]
# cessing Bearing1_3:  21% 507/2375 [00:01<00:05, 320.91it/s]
# cessing Bearing1_3:  23% 540/2375 [00:01<00:05, 317.13it/s]
# cessing Bearing1_3:  24% 575/2375 [00:01<00:05, 326.06it/s]
# cessing Bearing1_3:  26% 609/2375 [00:01<00:05, 313.16it/s]
# cessing Bearing1_3:  27% 641/2375 [00:01<00:05, 314.48it/s]
# cessing Bearing1_3:  28% 673/2375 [00:02<00:05, 310.74it/s]
# cessing Bearing1_3:  30% 705/2375 [00:02<00:05, 312.18it/s]
# cessing Bearing1_3:  31% 737/2375 [00:02<00:05, 314.13it/s]
# cessing Bearing1_3:  32% 770/2375 [00:02<00:05, 316.98it/s]
# cessing Bearing1_3:  34% 802/2375 [00:02<00:05, 313.29it/s]
# cessing Bearing1_3:  35% 834/2375 [00:02<00:05, 306.94it/s]
# cessing Bearing1_3:  37% 867/2375 [00:02<00:04, 311.82it/s]
# cessing Bearing1_3:  38% 899/2375 [00:02<00:04, 311.19it/s]
# cessing Bearing1_3:  39% 931/2375 [00:02<00:04, 307.36it/s]
# cessing Bearing1_3:  41% 962/2375 [00:03<00:04, 306.54it/s]
# cessing Bearing1_3:  42% 995/2375 [00:03<00:04, 312.68it/s]
# cessing Bearing1_3:  43% 1029/2375 [00:03<00:04, 319.96it/s]
# cessing Bearing1_3:  45% 1062/2375 [00:03<00:04, 318.88it/s]
# cessing Bearing1_3:  46% 1094/2375 [00:03<00:04, 318.23it/s]
# cessing Bearing1_3:  47% 1126/2375 [00:03<00:03, 316.18it/s]
# cessing Bearing1_3:  49% 1160/2375 [00:03<00:03, 320.89it/s]
# cessing Bearing1_3:  50% 1193/2375 [00:03<00:03, 319.99it/s]
# cessing Bearing1_3:  52% 1228/2375 [00:03<00:03, 321.00it/s]
# cessing Bearing1_3:  53% 1261/2375 [00:03<00:03, 307.24it/s]
# cessing Bearing1_3:  55% 1296/2375 [00:04<00:03, 318.47it/s]
# cessing Bearing1_3:  56% 1329/2375 [00:04<00:03, 321.50it/s]
# cessing Bearing1_3:  57% 1362/2375 [00:04<00:03, 322.99it/s]
# cessing Bearing1_3:  59% 1397/2375 [00:04<00:02, 328.19it/s]
# cessing Bearing1_3:  60% 1430/2375 [00:04<00:02, 325.09it/s]
# cessing Bearing1_3:  62% 1463/2375 [00:04<00:02, 325.89it/s]
# cessing Bearing1_3:  63% 1496/2375 [00:04<00:02, 325.65it/s]
# cessing Bearing1_3:  64% 1529/2375 [00:04<00:02, 325.13it/s]
# cessing Bearing1_3:  66% 1562/2375 [00:04<00:02, 321.63it/s]
# cessing Bearing1_3:  67% 1595/2375 [00:05<00:02, 308.15it/s]
# cessing Bearing1_3:  69% 1629/2375 [00:05<00:02, 314.89it/s]
# cessing Bearing1_3:  70% 1661/2375 [00:05<00:02, 308.53it/s]
# cessing Bearing1_3:  71% 1695/2375 [00:05<00:02, 315.69it/s]
# cessing Bearing1_3:  73% 1727/2375 [00:05<00:02, 315.33it/s]
# cessing Bearing1_3:  74% 1760/2375 [00:05<00:01, 319.30it/s]
# cessing Bearing1_3:  75% 1792/2375 [00:05<00:01, 319.03it/s]
# cessing Bearing1_3:  77% 1826/2375 [00:05<00:01, 323.45it/s]
# cessing Bearing1_3:  78% 1859/2375 [00:05<00:01, 322.25it/s]
# cessing Bearing1_3:  80% 1892/2375 [00:05<00:01, 308.63it/s]
# cessing Bearing1_3:  81% 1926/2375 [00:06<00:01, 315.40it/s]
# cessing Bearing1_3:  82% 1959/2375 [00:06<00:01, 318.43it/s]
# cessing Bearing1_3:  84% 1994/2375 [00:06<00:01, 325.17it/s]
# cessing Bearing1_3:  85% 2029/2375 [00:06<00:01, 329.92it/s]
# cessing Bearing1_3:  87% 2063/2375 [00:06<00:00, 331.95it/s]
# cessing Bearing1_3:  88% 2097/2375 [00:06<00:00, 329.43it/s]
# cessing Bearing1_3:  90% 2130/2375 [00:06<00:00, 329.21it/s]
# cessing Bearing1_3:  91% 2163/2375 [00:06<00:00, 326.11it/s]
# cessing Bearing1_3:  92% 2196/2375 [00:06<00:00, 324.48it/s]
# cessing Bearing1_3:  94% 2229/2375 [00:06<00:00, 322.94it/s]
# cessing Bearing1_3:  95% 2262/2375 [00:07<00:00, 320.29it/s]
# cessing Bearing1_3:  97% 2295/2375 [00:07<00:00, 322.72it/s]
# cessing Bearing1_3:  98% 2328/2375 [00:07<00:00, 316.71it/s]
# cessing Bearing1_3:  99% 2360/2375 [00:07<00:00, 316.18it/s]
# Overall Progress:  43% 3/7 [00:20<00:26,  6.57s/it]
# cessing Bearing1_4:   0% 0/1428 [00:00<?, ?it/s]
# cessing Bearing1_4:   2% 33/1428 [00:00<00:04, 323.61it/s]
# Error processing file Full_Test_Set/Bearing1_4/acc_00001.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00002.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00003.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00004.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00005.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00006.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00007.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00008.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00009.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00010.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00011.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00012.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00013.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00014.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00015.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00016.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00017.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00018.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00019.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00020.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00021.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00022.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00023.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00024.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00025.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00026.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00027.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00028.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00029.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00030.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00031.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00032.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00033.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00034.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00035.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00036.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00037.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00038.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00039.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00040.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00041.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00042.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00043.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00044.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00045.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00046.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00047.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00048.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00049.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00050.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00051.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00052.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00053.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00054.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00055.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00056.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00057.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00058.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00059.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00060.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00061.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00062.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00063.csv: single positional indexer is out-of-bounds
# cessing Bearing1_4:   5% 66/1428 [00:00<00:04, 306.08it/s]
# cessing Bearing1_4:   7% 97/1428 [00:00<00:04, 305.59it/s]
# Error processing file Full_Test_Set/Bearing1_4/acc_00064.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00065.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00066.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00067.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00068.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00069.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00070.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00071.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00072.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00073.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00074.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00075.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00076.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00077.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00078.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00079.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00080.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00081.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00082.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00083.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00084.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00085.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00086.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00087.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00088.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00089.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00090.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00091.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00092.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00093.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00094.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00095.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00096.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00097.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00098.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00099.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00100.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00101.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00102.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00103.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00104.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00105.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00106.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00107.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00108.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00109.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00110.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00111.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00112.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00113.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00114.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00115.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00116.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00117.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00118.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00119.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00120.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00121.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00122.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00123.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00124.csv: single positional indexer is out-of-bounds
# cessing Bearing1_4:   9% 128/1428 [00:00<00:04, 303.84it/s]
# cessing Bearing1_4:  11% 159/1428 [00:00<00:04, 305.24it/s]
# Error processing file Full_Test_Set/Bearing1_4/acc_00125.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00126.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00127.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00128.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00129.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00130.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00131.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00132.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00133.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00134.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00135.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00136.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00137.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00138.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00139.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00140.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00141.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00142.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00143.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00144.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00145.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00146.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00147.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00148.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00149.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00150.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00151.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00152.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00153.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00154.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00155.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00156.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00157.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00158.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00159.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00160.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00161.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00162.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00163.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00164.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00165.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00166.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00167.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00168.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00169.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00170.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00171.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00172.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00173.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00174.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00175.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00176.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00177.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00178.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00179.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00180.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00181.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00182.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00183.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00184.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00185.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00186.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00187.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00188.csv: single positional indexer is out-of-bounds
# cessing Bearing1_4:  13% 192/1428 [00:00<00:03, 311.99it/s]
# cessing Bearing1_4:  16% 224/1428 [00:00<00:03, 311.27it/s]
# Error processing file Full_Test_Set/Bearing1_4/acc_00189.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00190.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00191.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00192.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00193.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00194.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00195.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00196.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00197.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00198.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00199.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00200.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00201.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00202.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00203.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00204.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00205.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00206.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00207.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00208.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00209.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00210.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00211.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00212.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00213.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00214.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00215.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00216.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00217.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00218.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00219.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00220.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00221.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00222.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00223.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00224.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00225.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00226.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00227.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00228.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00229.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00230.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00231.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00232.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00233.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00234.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00235.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00236.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00237.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00238.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00239.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00240.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00241.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00242.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00243.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00244.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00245.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00246.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00247.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00248.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00249.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00250.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00251.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00252.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00253.csv: single positional indexer is out-of-bounds
# cessing Bearing1_4:  18% 257/1428 [00:00<00:03, 316.77it/s]
# cessing Bearing1_4:  20% 289/1428 [00:00<00:03, 316.55it/s]
# Error processing file Full_Test_Set/Bearing1_4/acc_00254.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00255.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00256.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00257.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00258.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00259.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00260.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00261.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00262.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00263.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00264.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00265.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00266.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00267.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00268.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00269.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00270.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00271.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00272.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00273.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00274.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00275.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00276.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00277.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00278.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00279.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00280.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00281.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00282.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00283.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00284.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00285.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00286.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00287.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00288.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00289.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00290.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00291.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00292.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00293.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00294.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00295.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00296.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00297.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00298.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00299.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00300.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00301.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00302.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00303.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00304.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00305.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00306.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00307.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00308.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00309.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00310.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00311.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00312.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00313.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00314.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00315.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00316.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00317.csv: single positional indexer is out-of-bounds
# cessing Bearing1_4:  22% 321/1428 [00:01<00:03, 314.29it/s]
# cessing Bearing1_4:  25% 353/1428 [00:01<00:03, 311.11it/s]
# Error processing file Full_Test_Set/Bearing1_4/acc_00318.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00319.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00320.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00321.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00322.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00323.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00324.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00325.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00326.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00327.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00328.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00329.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00330.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00331.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00332.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00333.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00334.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00335.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00336.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00337.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_00338.csv: single positional indexer is out-of-bounds
# ...
# Error processing file Full_Test_Set/Bearing1_4/acc_01420.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01421.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01422.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01423.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01424.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01425.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01426.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01427.csv: single positional indexer is out-of-bounds
# Error processing file Full_Test_Set/Bearing1_4/acc_01428.csv: single positional indexer is out-of-bounds
# cessing Bearing1_5:   0% 0/2463 [00:00<?, ?it/s]
# cessing Bearing1_5:   1% 30/2463 [00:00<00:08, 299.27it/s]
# cessing Bearing1_5:   2% 61/2463 [00:00<00:08, 300.10it/s]
# cessing Bearing1_5:   4% 92/2463 [00:00<00:08, 285.19it/s]
# cessing Bearing1_5:   5% 121/2463 [00:00<00:08, 285.62it/s]
# cessing Bearing1_5:   6% 154/2463 [00:00<00:07, 297.31it/s]
# cessing Bearing1_5:   7% 184/2463 [00:00<00:08, 276.51it/s]
# cessing Bearing1_5:   9% 213/2463 [00:00<00:08, 277.69it/s]
# cessing Bearing1_5:  10% 243/2463 [00:00<00:07, 283.99it/s]
# cessing Bearing1_5:  11% 274/2463 [00:00<00:07, 291.30it/s]
# cessing Bearing1_5:  12% 307/2463 [00:01<00:07, 301.28it/s]
# cessing Bearing1_5:  14% 338/2463 [00:01<00:07, 299.92it/s]
# cessing Bearing1_5:  15% 371/2463 [00:01<00:06, 306.99it/s]
# cessing Bearing1_5:  16% 402/2463 [00:01<00:06, 305.63it/s]
# cessing Bearing1_5:  18% 433/2463 [00:01<00:07, 285.33it/s]
# cessing Bearing1_5:  19% 464/2463 [00:01<00:06, 290.91it/s]
# cessing Bearing1_5:  20% 494/2463 [00:01<00:06, 287.09it/s]
# cessing Bearing1_5:  21% 523/2463 [00:01<00:06, 284.59it/s]
# cessing Bearing1_5:  22% 554/2463 [00:01<00:06, 289.94it/s]
# cessing Bearing1_5:  24% 588/2463 [00:02<00:06, 301.93it/s]
# cessing Bearing1_5:  25% 621/2463 [00:02<00:05, 309.09it/s]
# cessing Bearing1_5:  26% 652/2463 [00:02<00:05, 308.43it/s]
# cessing Bearing1_5:  28% 684/2463 [00:02<00:05, 310.60it/s]
# cessing Bearing1_5:  29% 716/2463 [00:02<00:05, 309.20it/s]
# cessing Bearing1_5:  30% 747/2463 [00:02<00:05, 303.08it/s]
# cessing Bearing1_5:  32% 778/2463 [00:02<00:05, 299.64it/s]
# cessing Bearing1_5:  33% 808/2463 [00:02<00:05, 295.48it/s]
# cessing Bearing1_5:  34% 838/2463 [00:02<00:05, 295.57it/s]
# cessing Bearing1_5:  35% 870/2463 [00:02<00:05, 300.61it/s]
# cessing Bearing1_5:  37% 901/2463 [00:03<00:05, 297.14it/s]
# cessing Bearing1_5:  38% 931/2463 [00:03<00:05, 294.39it/s]
# cessing Bearing1_5:  39% 962/2463 [00:03<00:05, 298.79it/s]
# cessing Bearing1_5:  40% 992/2463 [00:03<00:04, 294.26it/s]
# cessing Bearing1_5:  41% 1022/2463 [00:03<00:04, 294.02it/s]
# cessing Bearing1_5:  43% 1052/2463 [00:03<00:04, 295.26it/s]
# cessing Bearing1_5:  44% 1082/2463 [00:03<00:04, 296.58it/s]
# cessing Bearing1_5:  45% 1112/2463 [00:03<00:04, 294.03it/s]
# cessing Bearing1_5:  46% 1142/2463 [00:03<00:04, 289.62it/s]
# cessing Bearing1_5:  48% 1171/2463 [00:03<00:04, 283.62it/s]
# cessing Bearing1_5:  49% 1200/2463 [00:04<00:04, 283.40it/s]
# cessing Bearing1_5:  50% 1229/2463 [00:04<00:04, 284.95it/s]
# cessing Bearing1_5:  51% 1259/2463 [00:04<00:04, 288.63it/s]
# cessing Bearing1_5:  52% 1289/2463 [00:04<00:04, 287.52it/s]
# cessing Bearing1_5:  54% 1319/2463 [00:04<00:03, 290.99it/s]
# cessing Bearing1_5:  55% 1349/2463 [00:04<00:03, 287.44it/s]
# cessing Bearing1_5:  56% 1378/2463 [00:04<00:03, 278.63it/s]
# cessing Bearing1_5:  57% 1406/2463 [00:04<00:03, 277.90it/s]
# cessing Bearing1_5:  58% 1434/2463 [00:04<00:03, 275.16it/s]
# cessing Bearing1_5:  59% 1462/2463 [00:05<00:03, 274.64it/s]
# cessing Bearing1_5:  61% 1491/2463 [00:05<00:03, 279.05it/s]
# cessing Bearing1_5:  62% 1521/2463 [00:05<00:03, 282.44it/s]
# cessing Bearing1_5:  63% 1550/2463 [00:05<00:03, 278.38it/s]
# cessing Bearing1_5:  64% 1578/2463 [00:05<00:03, 274.24it/s]
# cessing Bearing1_5:  65% 1608/2463 [00:05<00:03, 280.42it/s]
# cessing Bearing1_5:  66% 1637/2463 [00:05<00:02, 280.49it/s]
# cessing Bearing1_5:  68% 1666/2463 [00:05<00:02, 277.97it/s]
# cessing Bearing1_5:  69% 1694/2463 [00:05<00:02, 278.37it/s]
# cessing Bearing1_5:  70% 1724/2463 [00:05<00:02, 282.67it/s]
# cessing Bearing1_5:  71% 1753/2463 [00:06<00:02, 284.71it/s]
# cessing Bearing1_5:  72% 1782/2463 [00:06<00:02, 281.65it/s]
# cessing Bearing1_5:  74% 1811/2463 [00:06<00:02, 246.82it/s]
# cessing Bearing1_5:  75% 1839/2463 [00:06<00:02, 255.32it/s]
# cessing Bearing1_5:  76% 1866/2463 [00:06<00:02, 256.92it/s]
# cessing Bearing1_5:  77% 1894/2463 [00:06<00:02, 263.25it/s]
# cessing Bearing1_5:  78% 1923/2463 [00:06<00:02, 269.28it/s]
# cessing Bearing1_5:  79% 1952/2463 [00:06<00:01, 275.15it/s]
# cessing Bearing1_5:  80% 1980/2463 [00:06<00:01, 273.33it/s]
# cessing Bearing1_5:  82% 2008/2463 [00:07<00:01, 274.46it/s]
# cessing Bearing1_5:  83% 2036/2463 [00:07<00:01, 264.17it/s]
# cessing Bearing1_5:  84% 2063/2463 [00:07<00:01, 257.64it/s]
# cessing Bearing1_5:  85% 2092/2463 [00:07<00:01, 265.70it/s]
# cessing Bearing1_5:  86% 2122/2463 [00:07<00:01, 273.38it/s]
# cessing Bearing1_5:  87% 2150/2463 [00:07<00:01, 274.18it/s]
# cessing Bearing1_5:  88% 2179/2463 [00:07<00:01, 277.28it/s]
# cessing Bearing1_5:  90% 2207/2463 [00:07<00:00, 276.41it/s]
# cessing Bearing1_5:  91% 2235/2463 [00:07<00:00, 274.23it/s]
# cessing Bearing1_5:  92% 2264/2463 [00:07<00:00, 277.15it/s]
# cessing Bearing1_5:  93% 2292/2463 [00:08<00:00, 272.79it/s]
# cessing Bearing1_5:  94% 2320/2463 [00:08<00:00, 270.23it/s]
# cessing Bearing1_5:  95% 2349/2463 [00:08<00:00, 274.81it/s]
# cessing Bearing1_5:  97% 2379/2463 [00:08<00:00, 280.84it/s]
# cessing Bearing1_5:  98% 2408/2463 [00:08<00:00, 280.94it/s]
# cessing Bearing1_5:  99% 2438/2463 [00:08<00:00, 284.57it/s]
# Overall Progress:  71% 5/7 [00:33<00:13,  6.99s/it]
# cessing Bearing1_6:   0% 0/2448 [00:00<?, ?it/s]
# cessing Bearing1_6:   1% 30/2448 [00:00<00:08, 298.91it/s]
# cessing Bearing1_6:   3% 62/2448 [00:00<00:07, 310.87it/s]
# cessing Bearing1_6:   4% 94/2448 [00:00<00:07, 314.59it/s]
# cessing Bearing1_6:   5% 126/2448 [00:00<00:07, 307.93it/s]
# cessing Bearing1_6:   6% 159/2448 [00:00<00:07, 314.56it/s]
# cessing Bearing1_6:   8% 191/2448 [00:00<00:07, 307.66it/s]
# cessing Bearing1_6:   9% 222/2448 [00:00<00:07, 303.06it/s]
# cessing Bearing1_6:  10% 253/2448 [00:00<00:07, 301.33it/s]
# cessing Bearing1_6:  12% 284/2448 [00:00<00:07, 303.85it/s]
# cessing Bearing1_6:  13% 316/2448 [00:01<00:06, 306.69it/s]
# cessing Bearing1_6:  14% 347/2448 [00:01<00:06, 307.40it/s]
# cessing Bearing1_6:  16% 381/2448 [00:01<00:06, 315.18it/s]
# cessing Bearing1_6:  17% 414/2448 [00:01<00:06, 317.27it/s]
# cessing Bearing1_6:  18% 446/2448 [00:01<00:06, 317.96it/s]
# cessing Bearing1_6:  20% 478/2448 [00:01<00:06, 313.92it/s]
# cessing Bearing1_6:  21% 510/2448 [00:01<00:06, 311.57it/s]
# cessing Bearing1_6:  22% 542/2448 [00:01<00:06, 306.97it/s]
# cessing Bearing1_6:  23% 573/2448 [00:01<00:06, 300.67it/s]
# cessing Bearing1_6:  25% 605/2448 [00:01<00:06, 302.96it/s]
# cessing Bearing1_6:  26% 638/2448 [00:02<00:05, 309.01it/s]
# cessing Bearing1_6:  27% 669/2448 [00:02<00:05, 308.79it/s]
# cessing Bearing1_6:  29% 700/2448 [00:02<00:05, 301.34it/s]
# cessing Bearing1_6:  30% 731/2448 [00:02<00:05, 300.16it/s]
# cessing Bearing1_6:  31% 762/2448 [00:02<00:05, 299.92it/s]
# cessing Bearing1_6:  32% 794/2448 [00:02<00:05, 304.48it/s]
# cessing Bearing1_6:  34% 826/2448 [00:02<00:05, 308.53it/s]
# cessing Bearing1_6:  35% 857/2448 [00:02<00:05, 307.75it/s]
# cessing Bearing1_6:  36% 889/2448 [00:02<00:05, 308.15it/s]
# cessing Bearing1_6:  38% 922/2448 [00:02<00:04, 311.65it/s]
# cessing Bearing1_6:  39% 954/2448 [00:03<00:04, 313.45it/s]
# cessing Bearing1_6:  40% 986/2448 [00:03<00:04, 308.87it/s]
# cessing Bearing1_6:  42% 1017/2448 [00:03<00:04, 299.23it/s]
# cessing Bearing1_6:  43% 1047/2448 [00:03<00:04, 288.07it/s]
# cessing Bearing1_6:  44% 1076/2448 [00:03<00:04, 286.19it/s]
# cessing Bearing1_6:  45% 1105/2448 [00:03<00:05, 263.73it/s]
# cessing Bearing1_6:  46% 1132/2448 [00:03<00:05, 241.82it/s]
# cessing Bearing1_6:  47% 1157/2448 [00:03<00:05, 236.05it/s]
# cessing Bearing1_6:  48% 1187/2448 [00:04<00:05, 251.99it/s]
# cessing Bearing1_6:  50% 1217/2448 [00:04<00:04, 264.24it/s]
# cessing Bearing1_6:  51% 1244/2448 [00:04<00:04, 259.03it/s]
# cessing Bearing1_6:  52% 1273/2448 [00:04<00:04, 265.92it/s]
# cessing Bearing1_6:  53% 1300/2448 [00:04<00:04, 263.75it/s]
# cessing Bearing1_6:  54% 1327/2448 [00:04<00:04, 247.93it/s]
# cessing Bearing1_6:  55% 1353/2448 [00:04<00:05, 196.59it/s]
# cessing Bearing1_6:  56% 1382/2448 [00:04<00:04, 217.20it/s]
# cessing Bearing1_6:  58% 1409/2448 [00:04<00:04, 229.16it/s]
# cessing Bearing1_6:  59% 1439/2448 [00:05<00:04, 247.37it/s]
# cessing Bearing1_6:  60% 1469/2448 [00:05<00:03, 261.50it/s]
# cessing Bearing1_6:  61% 1500/2448 [00:05<00:03, 273.17it/s]
# cessing Bearing1_6:  62% 1529/2448 [00:05<00:03, 264.39it/s]
# cessing Bearing1_6:  64% 1557/2448 [00:05<00:03, 264.64it/s]
# cessing Bearing1_6:  65% 1584/2448 [00:05<00:03, 264.83it/s]
# cessing Bearing1_6:  66% 1613/2448 [00:05<00:03, 270.03it/s]
# cessing Bearing1_6:  67% 1641/2448 [00:05<00:03, 268.63it/s]
# cessing Bearing1_6:  68% 1669/2448 [00:05<00:02, 269.79it/s]
# cessing Bearing1_6:  69% 1697/2448 [00:06<00:03, 234.35it/s]
# cessing Bearing1_6:  70% 1722/2448 [00:06<00:03, 217.84it/s]
# cessing Bearing1_6:  71% 1746/2448 [00:06<00:03, 218.09it/s]
# cessing Bearing1_6:  72% 1769/2448 [00:06<00:03, 174.02it/s]
# cessing Bearing1_6:  73% 1795/2448 [00:06<00:03, 192.38it/s]
# cessing Bearing1_6:  75% 1824/2448 [00:06<00:02, 215.25it/s]
# cessing Bearing1_6:  76% 1854/2448 [00:06<00:02, 235.29it/s]
# cessing Bearing1_6:  77% 1885/2448 [00:06<00:02, 253.37it/s]
# cessing Bearing1_6:  78% 1915/2448 [00:07<00:02, 264.02it/s]
# cessing Bearing1_6:  79% 1944/2448 [00:07<00:01, 269.44it/s]
# cessing Bearing1_6:  81% 1972/2448 [00:07<00:01, 268.73it/s]
# cessing Bearing1_6:  82% 2001/2448 [00:07<00:01, 274.12it/s]
# cessing Bearing1_6:  83% 2029/2448 [00:07<00:01, 274.82it/s]
# cessing Bearing1_6:  84% 2057/2448 [00:07<00:01, 275.72it/s]
# cessing Bearing1_6:  85% 2087/2448 [00:07<00:01, 282.35it/s]
# cessing Bearing1_6:  86% 2116/2448 [00:07<00:01, 273.45it/s]
# cessing Bearing1_6:  88% 2144/2448 [00:07<00:01, 274.45it/s]
# cessing Bearing1_6:  89% 2174/2448 [00:07<00:00, 279.37it/s]
# cessing Bearing1_6:  90% 2204/2448 [00:08<00:00, 283.85it/s]
# cessing Bearing1_6:  91% 2233/2448 [00:08<00:00, 280.09it/s]
# cessing Bearing1_6:  92% 2262/2448 [00:08<00:00, 277.48it/s]
# cessing Bearing1_6:  94% 2291/2448 [00:08<00:00, 279.10it/s]
# cessing Bearing1_6:  95% 2320/2448 [00:08<00:00, 279.99it/s]
# cessing Bearing1_6:  96% 2350/2448 [00:08<00:00, 284.15it/s]
# cessing Bearing1_6:  97% 2381/2448 [00:08<00:00, 290.80it/s]
# cessing Bearing1_6:  99% 2412/2448 [00:08<00:00, 295.78it/s]
# cessing Bearing1_6: 100% 2442/2448 [00:08<00:00, 294.44it/s]
# Overall Progress:  86% 6/7 [00:43<00:07,  7.71s/it]
# cessing Bearing1_7:   0% 0/2259 [00:00<?, ?it/s]
# cessing Bearing1_7:   1% 33/2259 [00:00<00:06, 325.11it/s]
# cessing Bearing1_7:   3% 66/2259 [00:00<00:06, 325.43it/s]
# cessing Bearing1_7:   4% 100/2259 [00:00<00:06, 328.97it/s]
# cessing Bearing1_7:   6% 133/2259 [00:00<00:06, 317.78it/s]
# cessing Bearing1_7:   7% 165/2259 [00:00<00:06, 314.27it/s]
# cessing Bearing1_7:   9% 197/2259 [00:00<00:06, 308.64it/s]
# cessing Bearing1_7:  10% 230/2259 [00:00<00:06, 313.48it/s]
# cessing Bearing1_7:  12% 262/2259 [00:00<00:06, 307.42it/s]
# cessing Bearing1_7:  13% 293/2259 [00:00<00:06, 307.81it/s]
# cessing Bearing1_7:  14% 324/2259 [00:01<00:06, 306.74it/s]
# cessing Bearing1_7:  16% 357/2259 [00:01<00:06, 311.63it/s]
# cessing Bearing1_7:  17% 390/2259 [00:01<00:05, 316.28it/s]
# cessing Bearing1_7:  19% 422/2259 [00:01<00:05, 316.30it/s]
# cessing Bearing1_7:  20% 454/2259 [00:01<00:05, 311.83it/s]
# cessing Bearing1_7:  22% 486/2259 [00:01<00:06, 291.70it/s]
# cessing Bearing1_7:  23% 517/2259 [00:01<00:05, 295.46it/s]
# cessing Bearing1_7:  24% 547/2259 [00:01<00:05, 290.56it/s]
# cessing Bearing1_7:  26% 577/2259 [00:01<00:05, 289.85it/s]
# cessing Bearing1_7:  27% 609/2259 [00:01<00:05, 296.24it/s]
# cessing Bearing1_7:  28% 641/2259 [00:02<00:05, 302.57it/s]
# cessing Bearing1_7:  30% 673/2259 [00:02<00:05, 306.20it/s]
# cessing Bearing1_7:  31% 704/2259 [00:02<00:05, 307.24it/s]
# cessing Bearing1_7:  33% 735/2259 [00:02<00:04, 306.64it/s]
# cessing Bearing1_7:  34% 766/2259 [00:02<00:04, 303.49it/s]
# cessing Bearing1_7:  35% 797/2259 [00:02<00:04, 300.39it/s]
# cessing Bearing1_7:  37% 828/2259 [00:02<00:04, 295.75it/s]
# cessing Bearing1_7:  38% 859/2259 [00:02<00:04, 298.78it/s]
# cessing Bearing1_7:  39% 890/2259 [00:02<00:04, 299.31it/s]
# cessing Bearing1_7:  41% 921/2259 [00:03<00:04, 300.13it/s]
# cessing Bearing1_7:  42% 952/2259 [00:03<00:04, 302.58it/s]
# cessing Bearing1_7:  44% 983/2259 [00:03<00:04, 300.82it/s]
# cessing Bearing1_7:  45% 1014/2259 [00:03<00:04, 290.68it/s]
# cessing Bearing1_7:  46% 1044/2259 [00:03<00:04, 291.01it/s]
# cessing Bearing1_7:  48% 1074/2259 [00:03<00:04, 286.13it/s]
# cessing Bearing1_7:  49% 1103/2259 [00:03<00:04, 283.76it/s]
# cessing Bearing1_7:  50% 1132/2259 [00:03<00:04, 272.53it/s]
# cessing Bearing1_7:  51% 1160/2259 [00:03<00:04, 273.51it/s]
# cessing Bearing1_7:  53% 1188/2259 [00:03<00:03, 275.06it/s]
# cessing Bearing1_7:  54% 1216/2259 [00:04<00:03, 274.62it/s]
# cessing Bearing1_7:  55% 1244/2259 [00:04<00:03, 264.71it/s]
# cessing Bearing1_7:  56% 1273/2259 [00:04<00:03, 269.94it/s]
# cessing Bearing1_7:  58% 1301/2259 [00:04<00:03, 265.02it/s]
# cessing Bearing1_7:  59% 1328/2259 [00:04<00:03, 252.08it/s]
# cessing Bearing1_7:  60% 1354/2259 [00:04<00:03, 250.31it/s]
# cessing Bearing1_7:  61% 1382/2259 [00:04<00:03, 257.25it/s]
# cessing Bearing1_7:  63% 1412/2259 [00:04<00:03, 268.42it/s]
# cessing Bearing1_7:  64% 1442/2259 [00:04<00:02, 275.19it/s]
# cessing Bearing1_7:  65% 1470/2259 [00:05<00:02, 273.49it/s]
# cessing Bearing1_7:  66% 1498/2259 [00:05<00:02, 272.31it/s]
# cessing Bearing1_7:  68% 1527/2259 [00:05<00:02, 276.00it/s]
# cessing Bearing1_7:  69% 1556/2259 [00:05<00:02, 280.05it/s]
# cessing Bearing1_7:  70% 1587/2259 [00:05<00:02, 288.80it/s]
# cessing Bearing1_7:  72% 1617/2259 [00:05<00:02, 289.61it/s]
# cessing Bearing1_7:  73% 1646/2259 [00:05<00:02, 288.77it/s]
# cessing Bearing1_7:  74% 1675/2259 [00:05<00:02, 286.94it/s]
# cessing Bearing1_7:  75% 1704/2259 [00:05<00:01, 287.31it/s]
# cessing Bearing1_7:  77% 1733/2259 [00:05<00:01, 281.73it/s]
# cessing Bearing1_7:  78% 1762/2259 [00:06<00:01, 275.69it/s]
# cessing Bearing1_7:  79% 1790/2259 [00:06<00:01, 262.86it/s]
# cessing Bearing1_7:  80% 1817/2259 [00:06<00:01, 236.36it/s]
# cessing Bearing1_7:  82% 1842/2259 [00:06<00:01, 236.70it/s]
# cessing Bearing1_7:  83% 1869/2259 [00:06<00:01, 242.80it/s]
# cessing Bearing1_7:  84% 1897/2259 [00:06<00:01, 252.21it/s]
# cessing Bearing1_7:  85% 1923/2259 [00:06<00:01, 246.63it/s]
# cessing Bearing1_7:  86% 1950/2259 [00:06<00:01, 251.17it/s]
# cessing Bearing1_7:  87% 1976/2259 [00:06<00:01, 244.62it/s]
# cessing Bearing1_7:  89% 2004/2259 [00:07<00:01, 254.07it/s]
# cessing Bearing1_7:  90% 2033/2259 [00:07<00:00, 262.74it/s]
# cessing Bearing1_7:  91% 2064/2259 [00:07<00:00, 274.17it/s]
# cessing Bearing1_7:  93% 2093/2259 [00:07<00:00, 275.64it/s]
# cessing Bearing1_7:  94% 2121/2259 [00:07<00:00, 249.37it/s]
# cessing Bearing1_7:  95% 2149/2259 [00:07<00:00, 256.94it/s]
# cessing Bearing1_7:  96% 2177/2259 [00:07<00:00, 261.77it/s]
# cessing Bearing1_7:  98% 2205/2259 [00:07<00:00, 266.28it/s]
# cessing Bearing1_7:  99% 2232/2259 [00:07<00:00, 260.04it/s]
# Overall Progress: 100% 7/7 [00:51<00:00,  7.34s/it]
# ------------------------------
# Step 1: HI (Kurtosis, RMS) extraction complete!
# Check the results in /home/work/RUL_AL/Pronostia dataset/HI_preprocessed

# %% [markdown]
# 2단계 FPT 계산 코드

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json

# --- 1. 경로 및 파라미터 설정 ---
BASE_PATH = Path(".") 
HI_PATH = BASE_PATH / "HI_preprocessed"
OUTPUT_PATH = BASE_PATH # FPT 결과를 저장할 위치 (동일 폴더)

# FPT 탐지 파라미터 (논문 [55] 기반)
NORMAL_PERIOD_SIZE = 100 # 정상 상태로 간주할 초기 스냅샷 개수 (임의 설정, 조절 가능)
CONSECUTIVE_THRESHOLD = 3  # 3-시그마를 연속으로 3회 초과해야 함 (논문에서 l=2, 즉 l+1=3)

# 1단계에서 처리한 베어링 리스트
bearing_names = [
    "Bearing1_1", "Bearing1_2", "Bearing1_3", "Bearing1_4", 
    "Bearing1_5", "Bearing1_6", "Bearing1_7"
]

fpt_results = {} # FPT 결과를 저장할 딕셔너리

print("Starting Step 2: FPT Identification...")
print(f"Loading HI data from: {HI_PATH.resolve()}")
print(f"Normal period size: {NORMAL_PERIOD_SIZE} snapshots")
print(f"Consecutive threshold: {CONSECUTIVE_THRESHOLD} times")
print("-" * 30)

# --- 2. FPT 탐지 루프 ---
for bearing_name in bearing_names:
    hi_file_path = HI_PATH / f"{bearing_name}_hi.csv"
    
    if not hi_file_path.exists():
        print(f"Warning: HI file not found for {bearing_name}. Skipping.")
        continue

    try:
        # 1단계에서 저장한 HI 파일 로드
        hi_df = pd.read_csv(hi_file_path, index_col="snapshot_index")
        kurtosis_series = hi_df["kurtosis"]

        # 1. '정상' 구간 데이터 정의
        normal_data = kurtosis_series.iloc[:NORMAL_PERIOD_SIZE]

        # 2. 3-시그마 임계값 계산
        mu = normal_data.mean()
        sigma = normal_data.std()
        
        # 논문 [55]는 |kurtosis - mu| > 3*sigma 를 확인
        upper_threshold = mu + 3 * sigma
        lower_threshold = mu - 3 * sigma

        # 3. FPT 탐지
        consecutive_count = 0
        fpt = None # FPT (First Predicting Time)

        # 전체 데이터를 순회 (정상 구간 포함)
        for i, kurt_value in enumerate(kurtosis_series):
            
            # 3-시그마 범위를 벗어났는지 확인
            if not (lower_threshold <= kurt_value <= upper_threshold):
                consecutive_count += 1
            else:
                consecutive_count = 0 # 범위 안에 들어오면 리셋

            # 4. FPT 확정
            # 연속 횟수가 임계값에 도달했는지 확인
            if consecutive_count >= CONSECUTIVE_THRESHOLD:
                # FPT는 *연속 이탈이 시작된 첫 시점*
                fpt = i - CONSECUTIVE_THRESHOLD + 1
                break # 첫 번째 FPT를 찾았으므로 루프 중단
        
        # EoL (End of Life)는 마지막 스냅샷의 인덱스
        eol = len(kurtosis_series) - 1
        
        if fpt is not None:
            print(f"✅ Success: {bearing_name.ljust(12)} | FPT = {fpt} (EoL = {eol})")
            fpt_results[bearing_name] = {"fpt": fpt, "eol": eol}
        else:
            # FPT를 찾지 못한 경우 (EoL에 도달하기 전에 고장 신호가 명확하지 않음)
            print(f"⚠️ Failed:  {bearing_name.ljust(12)} | FPT not found. Using FPT = 0.")
            # FPT를 못찾으면 임시로 0 (첫번째 스냅샷)을 FPT로 설정
            fpt_results[bearing_name] = {"fpt": 0, "eol": eol}

    except Exception as e:
        print(f"Error processing {bearing_name}: {e}")

# --- 3. FPT 결과 저장 ---
output_file = OUTPUT_PATH / "fpt_results.json"
with open(output_file, 'w') as f:
    json.dump(fpt_results, f, indent=4)

print("-" * 30)
print("Step 2: FPT Identification complete!")
print(f"FPT results saved to: {output_file.resolve()}")
# Out:
# Starting Step 2: FPT Identification...
# Loading HI data from: /home/work/RUL_AL/Pronostia dataset/HI_preprocessed
# Normal period size: 100 snapshots
# Consecutive threshold: 3 times
# ------------------------------
# ✅ Success: Bearing1_1   | FPT = 1313 (EoL = 2802)
# ✅ Success: Bearing1_2   | FPT = 152 (EoL = 870)
# ✅ Success: Bearing1_3   | FPT = 1732 (EoL = 2374)
# Warning: HI file not found for Bearing1_4. Skipping.
# ✅ Success: Bearing1_5   | FPT = 2411 (EoL = 2462)
# ✅ Success: Bearing1_6   | FPT = 605 (EoL = 2447)
# ✅ Success: Bearing1_7   | FPT = 1191 (EoL = 2258)
# ------------------------------
# Step 2: FPT Identification complete!
# FPT results saved to: /home/work/RUL_AL/Pronostia dataset/fpt_results.json

# %% [markdown]
# 3단계 CWT(웨이블릿 변환) 코드

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json
from tqdm import tqdm
import h5py
import pywt
from skimage.transform import resize
from scipy import stats

# --- 1. 피처 추출 함수 정의 ---

def calculate_9_features(data):
    """
    하나의 스냅샷(raw_data, 2560개 샘플)에서
    Huang et al. [56] 기준의 9개 피처를 계산합니다.
    """
    features = {}
    
    # f1: RMS
    features['f1_rms'] = np.sqrt(np.mean(data**2))
    
    # f2: Energy
    features['f2_energy'] = np.sum(data**2)
    
    # f3: Entropy
    # 데이터를 100개의 구간으로 나눠 확률 분포를 근사
    counts, _ = np.histogram(data, bins=100)
    probs = counts / len(data)
    features['f3_entropy'] = stats.entropy(probs)
    
    # f4: Max absolute
    features['f4_max_abs'] = np.max(np.abs(data))
    
    # f5: Mean absolute
    features['f5_mean_abs'] = np.mean(np.abs(data))
    
    # f6: Standard deviation
    features['f6_std'] = np.std(data)
    
    # f7: Clearance factor
    # (np.mean(np.sqrt(np.abs(data)))**2)가 0이 되는 것을 방지
    clearance_den = np.mean(np.sqrt(np.abs(data)))**2
    if clearance_den == 0:
        features['f7_clearance'] = 0
    else:
        features['f7_clearance'] = np.max(np.abs(data)) / clearance_den

    # f_skew (f24: arccosh가 모호하여 skewness로 대체)
    features['f_skew'] = stats.skew(data)
    
    # f25: std(arcsinh)
    features['f25_std_arcsinh'] = np.std(np.arcsinh(data))
    
    # 9개 피처를 순서대로 정렬하여 리스트로 반환
    return list(features.values())

def calculate_cwt_image(data, wavelet='morl', scales=np.arange(1, 101), target_size=(80, 80)):
    """
    하나의 스냅샷(raw_data)에서 CWT를 적용하고
    80x80 이미지로 리사이징합니다.
    """
    # 1. CWT 수행 (Morlet 웨이블릿 사용)
    coefficients, _ = pywt.cwt(data, scales, wavelet)
    
    # 2. 크기(magnitude) 계산
    cwt_magnitude = np.abs(coefficients)
    
    # 3. 80x80 크기로 리사이징 (Bilinear Interpolation)
    # anti_aliasing=True로 설정하여 리샘플링 품질 향상
    resized_image = resize(cwt_magnitude, target_size, anti_aliasing=True)
    
    return resized_image

# --- 2. 경로 및 파라미터 설정 ---
BASE_PATH = Path(".")
LEARNING_SET_PATH = BASE_PATH / "Learning_set"
FULL_TEST_SET_PATH = BASE_PATH / "Full_Test_Set"
FPT_FILE = BASE_PATH / "fpt_results.json"
OUTPUT_FILE = BASE_PATH / "PRONOSTIA_preprocessed.h5"

# CWT 파라미터 (논문 [56] 기반)
CWT_WAVELET = 'morl' # Morlet 웨이블릿
CWT_SCALES = np.arange(1, 101) # 1부터 100까지의 스케일

print("Starting Step 3: Feature Extraction and Labeling...")
print(f"Loading FPT/EoL data from: {FPT_FILE.resolve()}")

# --- 3. FPT/EoL 데이터 로드 ---
with open(FPT_FILE, 'r') as f:
    fpt_results = json.load(f)

print(f"Found data for {len(fpt_results)} bearings: {list(fpt_results.keys())}")
print(f"Output will be saved to: {OUTPUT_FILE.resolve()}")
print("-" * 30)

# --- 4. HDF5 파일 열기 ---
# 'w' 모드: 파일이 이미 존재하면 덮어씁니다.
with h5py.File(OUTPUT_FILE, 'w') as hf:
    
    # --- 5. 메인 처리 루프 (베어링별) ---
    for bearing_name, info in fpt_results.items():
        fpt = info['fpt']
        eol = info['eol']
        
        # 열화 구간의 총 스냅샷 수
        total_life_deg = eol - fpt
        if total_life_deg <= 0:
            print(f"Warning: {bearing_name} has no degradation period (fpt={fpt}, eol={eol}). Skipping.")
            continue

        print(f"Processing {bearing_name}: {total_life_deg + 1} snapshots (from {fpt} to {eol})...")
        
        # 베어링 경로 찾기
        if bearing_name in ["Bearing1_1", "Bearing1_2"]:
            bearing_path = LEARNING_SET_PATH / bearing_name
        else:
            bearing_path = FULL_TEST_SET_PATH / bearing_name
            
        # 이 베어링의 데이터를 저장할 리스트 초기화
        X1_images_list = []
        X2_vectors_list = []
        y_labels_list = []
        
        # --- 6. 스냅샷별 루프 (FPT ~ EoL) ---
        for snapshot_idx in tqdm(range(fpt, eol + 1), desc=f"  Extracting {bearing_name}", leave=False):
            try:
                # 1. 레이블 (y) 생성
                # RULP (Remaining Useful Life Percentage)
                current_life_deg = snapshot_idx - fpt
                rul_percentage = 1.0 - (current_life_deg / total_life_deg)
                y_labels_list.append(rul_percentage)
                
                # 2. 원본 데이터 로드
                # 스냅샷 인덱스는 0부터 시작, 파일 이름은 1부터 시작
                file_name = f"acc_{snapshot_idx + 1:05d}.csv"
                file_path = bearing_path / file_name
                
                # 수평 진동(5번째 열) 데이터만 읽어서 Numpy 배열로 변환
                raw_data = pd.read_csv(file_path, header=None).iloc[:, 4].values
                
                # 3. Input 1 (이미지 X1) 생성
                img = calculate_cwt_image(raw_data, CWT_WAVELET, CWT_SCALES)
                X1_images_list.append(img)
                
                # 4. Input 2 (벡터 X2) 생성
                vec = calculate_9_features(raw_data)
                X2_vectors_list.append(vec)

            except Exception as e:
                print(f"Error processing {bearing_name}, file {file_name}: {e}")
                # 리스트에 불일치가 발생하지 않도록, 에러 시 3개 리스트 모두에서 마지막 요소 제거
                if y_labels_list: y_labels_list.pop()
                if X1_images_list: X1_images_list.pop()
                if X2_vectors_list: X2_vectors_list.pop()

        # --- 7. HDF5 파일에 저장 ---
        if X1_images_list: # 처리된 데이터가 있을 경우에만 저장
            # 리스트를 Numpy 배열로 변환
            X1_array = np.array(X1_images_list, dtype=np.float32)
            X2_array = np.array(X2_vectors_list, dtype=np.float32)
            y_array = np.array(y_labels_list, dtype=np.float32)
            
            # HDF5 파일에 베어링 이름으로 그룹 생성
            bearing_group = hf.create_group(bearing_name)
            
            # 각 데이터셋을 그룹에 저장
            bearing_group.create_dataset("X1_images", data=X1_array)
            bearing_group.create_dataset("X2_vectors", data=X2_array)
            bearing_group.create_dataset("y_labels", data=y_array)
            
            print(f"  > Saved {bearing_name} data to HDF5 (Samples: {len(y_array)})")

print("-" * 30)
print("Step 3: Feature Extraction complete!")
print(f"All data saved in: {OUTPUT_FILE.resolve()}")
# Out:
# Starting Step 3: Feature Extraction and Labeling...
# Loading FPT/EoL data from: /home/work/RUL_AL/Pronostia dataset/fpt_results.json
# Found data for 6 bearings: ['Bearing1_1', 'Bearing1_2', 'Bearing1_3', 'Bearing1_5', 'Bearing1_6', 'Bearing1_7']
# Output will be saved to: /home/work/RUL_AL/Pronostia dataset/PRONOSTIA_preprocessed.h5
# ------------------------------
# Processing Bearing1_1: 1489 snapshots (from 1314 to 2802)...
#   > Saved Bearing1_1 data to HDF5 (Samples: 1489)
# Processing Bearing1_2: 45 snapshots (from 826 to 870)...
#   > Saved Bearing1_2 data to HDF5 (Samples: 45)
# Processing Bearing1_3: 649 snapshots (from 1726 to 2374)...
#   > Saved Bearing1_3 data to HDF5 (Samples: 649)
# Processing Bearing1_5: 51 snapshots (from 2412 to 2462)...
#   > Saved Bearing1_5 data to HDF5 (Samples: 51)
# Processing Bearing1_6: 817 snapshots (from 1631 to 2447)...
#   > Saved Bearing1_6 data to HDF5 (Samples: 817)
# Processing Bearing1_7: 49 snapshots (from 2210 to 2258)...
#   > Saved Bearing1_7 data to HDF5 (Samples: 49)
# ------------------------------
# Step 3: Feature Extraction complete!
# All data saved in: /home/work/RUL_AL/Pronostia dataset/PRONOSTIA_preprocessed.h5

# %% [markdown]
# 4단계(정규화)를 진행하는 코드

# %%
import h5py
import numpy as np
import json
from pathlib import Path

# --- 1. 경로 설정 ---
BASE_PATH = Path(".")
INPUT_FILE = BASE_PATH / "PRONOSTIA_preprocessed.h5"
SCALER_FILE = BASE_PATH / "x2_scaler.json" # X2 피처의 min/max 저장
OUTPUT_FILE = BASE_PATH / "PRONOSTIA_normalized.h5" # 최종 정규화된 파일

# --- 4.1: 스케일러(Min/Max) 계산 ---
print("Starting Step 4.1: Calculating global min/max scaler...")
print(f"Loading data from: {INPUT_FILE.resolve()}")

# 9개 피처의 global min/max를 저장할 변수
global_min = np.full(9, np.inf)
global_max = np.full(9, -np.inf)

try:
    with h5py.File(INPUT_FILE, 'r') as hf:
        bearing_names = list(hf.keys())
        if not bearing_names:
            print(f"Error: HDF5 file '{INPUT_FILE.name}' is empty.")
            exit() # 프로그램 중단

        for bearing_name in bearing_names:
            if 'X2_vectors' in hf[bearing_name]:
                x2_data = hf[bearing_name]['X2_vectors'][:]
                
                if x2_data.shape[0] > 0:
                    # 현재 베어링의 min/max 계산 (axis=0 : 피처별)
                    local_min = np.min(x2_data, axis=0)
                    local_max = np.max(x2_data, axis=0)
                    
                    # global min/max 업데이트
                    global_min = np.minimum(global_min, local_min)
                    global_max = np.maximum(global_max, local_max)
                else:
                    print(f"Warning: {bearing_name} X2_vectors is empty.")
            else:
                print(f"Warning: {bearing_name} has no X2_vectors dataset.")

    # --- 스케일러 저장 ---
    # 나중에 0으로 나누는 것을 방지하기 위해 (max - min) 계산
    data_range = global_max - global_min
    
    # 만약 min==max인 피처가 있다면 (값이 모두 동일), range를 1로 설정
    data_range[data_range == 0] = 1.0 
    
    scaler_data = {
        'min': global_min.tolist(),
        'range': data_range.tolist()
    }

    with open(SCALER_FILE, 'w') as f:
        json.dump(scaler_data, f, indent=4)
        
    print(f"Global Min (9 features): {global_min}")
    print(f"Global Max (9 features): {global_max}")
    print(f"Scaler data saved to: {SCALER_FILE.resolve()}")

except FileNotFoundError:
    print(f"Error: Input file not found at {INPUT_FILE.resolve()}. Run Step 3 first.")
    exit()
except Exception as e:
    print(f"An error occurred during scaler calculation: {e}")
    exit()

print("-" * 30)

# --- 4.2: 정규화 적용 및 최종 파일 저장 ---
print("Starting Step 4.2: Applying normalization...")
print(f"Loading scaler from: {SCALER_FILE.resolve()}")

try:
    # 1. 스케일러 로드
    min_vals = np.array(scaler_data['min'])
    range_vals = np.array(scaler_data['range'])

    # 2. 정규화 적용 및 새 HDF5 파일 저장
    with h5py.File(INPUT_FILE, 'r') as hf_in, h5py.File(OUTPUT_FILE, 'w') as hf_out:
        bearing_names = list(hf_in.keys())
        
        for bearing_name in bearing_names:
            if bearing_name not in hf_in or 'X1_images' not in hf_in[bearing_name]:
                print(f"Skipping {bearing_name}, data not found in source file.")
                continue

            # 1. 원본 데이터 로드
            x1_images = hf_in[bearing_name]['X1_images'][:]
            x2_vectors = hf_in[bearing_name]['X2_vectors'][:]
            y_labels = hf_in[bearing_name]['y_labels'][:]
            
            # 2. X2_vectors 정규화 (Min-Max Scaling)
            x2_vectors_norm = (x2_vectors - min_vals) / range_vals
            
            # 3. 새 HDF5 파일에 그룹 생성 및 저장
            bearing_group = hf_out.create_group(bearing_name)
            
            bearing_group.create_dataset("X1_images", data=x1_images, dtype='float32')
            bearing_group.create_dataset("X2_vectors_norm", data=x2_vectors_norm, dtype='float32')
            bearing_group.create_dataset("y_labels", data=y_labels, dtype='float32')

    print(f"Normalization complete!")
    print(f"Final normalized dataset saved to: {OUTPUT_FILE.resolve()}")

except Exception as e:
    print(f"An error occurred during normalization: {e}")

print("-" * 30)
print("Step 4 complete. You are now ready to load this data and train your model.")
# Out:
# Starting Step 4.1: Calculating global min/max scaler...
# Loading data from: /home/work/RUL_AL/Pronostia dataset/PRONOSTIA_preprocessed.h5
# Global Min (9 features): [  0.28064013 201.62272644   2.06824088   1.04200006   0.22076094
#    0.28056908   4.73460436  -6.49813223   0.27056485]
# Global Max (9 features): [1.03396826e+01 2.73687125e+05 4.17076254e+00 4.81479988e+01
#  7.83344221e+00 1.03220959e+01 4.03467064e+01 1.67827237e+00
#  2.55994296e+00]
# Scaler data saved to: /home/work/RUL_AL/Pronostia dataset/x2_scaler.json
# ------------------------------
# Starting Step 4.2: Applying normalization...
# Loading scaler from: /home/work/RUL_AL/Pronostia dataset/x2_scaler.json
# Normalization complete!
# Final normalized dataset saved to: /home/work/RUL_AL/Pronostia dataset/PRONOSTIA_normalized.h5
# ------------------------------
# Step 4 complete. You are now ready to load this data and train your model.

# %% [markdown]
# 5단계 reference 논문 Hybrid DCNN-based model 구축

# %%
import h5py
import numpy as np
import json
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, Dropout, BatchNormalization, Flatten, 
    Dense, Concatenate, ReLU
)
from sklearn.model_selection import train_test_split

# --- 1. 라이브러리 임포트 (위와 동일) ---

# --- 2. 데이터 로드 함수 ---
def load_data_from_hdf5(h5_path):
    """
    정규화된 HDF5 파일에서 6개 베어링 데이터를 모두 로드하여
    하나의 큰 학습 데이터셋으로 합칩니다.
    """
    X1_list = [] # 이미지 (80, 80)
    X2_list = [] # 벡터 (9,)
    y_list = []  # 레이블 (RULP)

    with h5py.File(h5_path, 'r') as hf:
        bearing_names = list(hf.keys())
        for bearing_name in bearing_names:
            X1_list.append(hf[bearing_name]['X1_images'][:])
            X2_list.append(hf[bearing_name]['X2_vectors_norm'][:])
            y_list.append(hf[bearing_name]['y_labels'][:])
    
    # 모든 베어링 데이터를 NumPy 배열로 결합
    X1_all = np.concatenate(X1_list, axis=0)
    X2_all = np.concatenate(X2_list, axis=0)
    y_all = np.concatenate(y_list, axis=0)
    
    # Keras Conv2D는 (batch, height, width, channels) 형식을 기대
    # 채널(grayscale) 차원(1)을 추가
    X1_all = np.expand_dims(X1_all, axis=-1)
    
    return X1_all, X2_all, y_all

# --- 3. DCNN-MLP 듀얼 네트워크 구축 함수 ---
def create_dcnn_mlp_model(input_shape_1=(80, 80, 1), input_shape_2=(9,)):
    """
    참조 논문 [56]의 Figure 8(c) 아키텍처를 기반으로 
    DCNN-MLP 듀얼 입력 모델을 생성합니다. 
    """
    
    # --- Input 1: DCNN (이미지) 타워 ---
    input_1 = Input(shape=input_shape_1, name='Input_1_Image') # [cite: 1373]

    x = Conv2D(12, (4, 4), strides=(2, 2), padding='same', activation='relu')(input_1) # [cite: 1377]
    x = Dropout(0.2)(x) # [cite: 1380]

    x = Conv2D(24, (4, 4), strides=(2, 2), padding='same', activation='relu')(x) # [cite: 1388]
    x = BatchNormalization()(x) # [cite: 1389]
    x = Dropout(0.2)(x) # [cite: 1390]

    x = Conv2D(48, (4, 4), strides=(5, 5), padding='same', activation='relu')(x) # [cite: 1393]
    x = BatchNormalization()(x) # [cite: 1397]
    x = Dropout(0.2)(x) # [cite: 1398]

    x = Conv2D(120, (4, 4), strides=(1, 1), padding='valid', activation='relu')(x) # [cite: 1403]
    
    cnn_out = Flatten(name='cnn_flatten')(x) # [cite: 1406]

    # --- Input 2: MLP (벡터) 타워 ---
    # (참고: 논문 그림 는 25개 피처 기준, 우리는 PRONOSTIA용 9개 피처 사용 )
    input_2 = Input(shape=input_shape_2, name='Input_2_Vector')

    y = Dense(50, activation='relu')(input_2) # [cite: 1417]
    y = Dropout(0.2)(y) # [cite: 1418]
    y = Dense(50, activation='relu')(y) # [cite: 1419]
    mlp_out = y

    # --- 융합 (Concatenate) ---
    concat = Concatenate(name='concatenate')([cnn_out, mlp_out]) # 

    # --- 출력 레이어 ---
    # RULP (0~1 사이)를 예측하므로 'sigmoid' 활성화 함수 사용
    output = Dense(1, activation='sigmoid', name='Output_RULP')(concat) # 

    # 모델 생성
    model = Model(inputs=[input_1, input_2], outputs=output)
    
    return model

# --- 4. 메인 실행 (로드, 빌드, 학습) ---
def main():
    # 4-1. 경로 설정
    HDF5_FILE = Path("PRONOSTIA_normalized.h5")
    
    # 4-2. 데이터 로드
    print("Loading normalized data...")
    if not HDF5_FILE.exists():
        print(f"Error: {HDF5_FILE.name} not found. Please run Step 3 & 4 first.")
        return
        
    X1_data, X2_data, y_data = load_data_from_hdf5(HDF5_FILE)
    print(f"Data loaded successfully.")
    print(f"  X1 (Images) shape: {X1_data.shape}")
    print(f"  X2 (Vectors) shape: {X2_data.shape}")
    print(f"  y (Labels) shape: {y_data.shape}")

    # 4-3. 학습/검증 데이터 분리 (80% 학습, 20% 검증)
    print("Splitting data into train/validation sets...")
    X1_train, X1_val, X2_train, X2_val, y_train, y_val = train_test_split(
        X1_data, X2_data, y_data, 
        test_size=0.2, 
        random_state=42 # 재현성을 위한 random_state
    )

    # 4-4. 모델 빌드 및 컴파일
    print("Building DCNN-MLP model...")
    # 우리 데이터는 9개 피처를 사용 
    model = create_dcnn_mlp_model(input_shape_1=(80, 80, 1), input_shape_2=(9,))
    model.summary() # 모델 구조 출력

    # 논문 [56]의 하이퍼파라미터(Table 4) 참조 
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    
    # RULP 예측은 회귀(regression) 문제이므로 'mean_squared_error' 사용
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

    # 4-5. 모델 학습
    print("Starting model training...")
    history = model.fit(
        [X1_train, X2_train], # 입력은 리스트 형태
        y_train,
        epochs=1500, # 논문은 1500 epoch, 여기선 100으로 축소
        batch_size=20, # [cite: 1441]
        validation_data=([X1_val, X2_val], y_val),
        callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)]
    )

    print("Training complete.")

    # 4-6. 모델 저장
    model.save("dcnn_mlp_baseline_model.h5")
    print("Model saved as 'dcnn_mlp_baseline_model.h5'")

if __name__ == "__main__":
    main()
# Out:
# Loading normalized data...
# Data loaded successfully.
#   X1 (Images) shape: (3100, 80, 80, 1)
#   X2 (Vectors) shape: (3100, 9)
#   y (Labels) shape: (3100,)
# Splitting data into train/validation sets...
# Building DCNN-MLP model...
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input_1_Image       │ (None, 80, 80, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 40, 40,    │        204 │ Input_1_Image[0]… │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 40, 40,    │          0 │ conv2d_4[0][0]    │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 20, 20,    │      4,632 │ dropout_4[0][0]   │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 20,    │         96 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 20, 20,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 4, 4, 48)  │     18,480 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 48)  │        192 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Input_2_Vector      │ (None, 9)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 4, 4, 48)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 50)        │        500 │ Input_2_Vector[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 1, 1, 120) │     92,280 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 50)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cnn_flatten         │ (None, 120)       │          0 │ conv2d_7[0][0]    │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 50)        │      2,550 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 170)       │          0 │ cnn_flatten[0][0… │
# │ (Concatenate)       │                   │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Output_RULP (Dense) │ (None, 1)         │        171 │ concatenate[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 119,105 (465.25 KB)
#  Trainable params: 118,961 (464.69 KB)
#  Non-trainable params: 144 (576.00 B)
# Starting model training...
# Epoch 1/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 0.0685 - mae: 0.2119 - val_loss: 0.0570 - val_mae: 0.1985
# Epoch 2/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0554 - mae: 0.1877 - val_loss: 0.0477 - val_mae: 0.1815
# Epoch 3/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0494 - mae: 0.1761 - val_loss: 0.0427 - val_mae: 0.1593
# Epoch 4/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0448 - mae: 0.1649 - val_loss: 0.0346 - val_mae: 0.1457
# Epoch 5/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0451 - mae: 0.1665 - val_loss: 0.0339 - val_mae: 0.1436
# Epoch 6/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0420 - mae: 0.1602 - val_loss: 0.0325 - val_mae: 0.1387
# Epoch 7/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0418 - mae: 0.1593 - val_loss: 0.0292 - val_mae: 0.1308
# Epoch 8/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0402 - mae: 0.1558 - val_loss: 0.0345 - val_mae: 0.1484
# Epoch 9/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0378 - mae: 0.1515 - val_loss: 0.0397 - val_mae: 0.1588
# Epoch 10/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0347 - mae: 0.1430 - val_loss: 0.0347 - val_mae: 0.1483
# Epoch 11/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0328 - mae: 0.1383 - val_loss: 0.0261 - val_mae: 0.1259
# Epoch 12/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0315 - mae: 0.1349 - val_loss: 0.0277 - val_mae: 0.1325
# Epoch 13/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0296 - mae: 0.1316 - val_loss: 0.0235 - val_mae: 0.1194
# Epoch 14/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0275 - mae: 0.1241 - val_loss: 0.0261 - val_mae: 0.1276
# Epoch 15/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0265 - mae: 0.1250 - val_loss: 0.0234 - val_mae: 0.1197
# Epoch 16/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0264 - mae: 0.1229 - val_loss: 0.0234 - val_mae: 0.1185
# Epoch 17/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0260 - mae: 0.1207 - val_loss: 0.0282 - val_mae: 0.1341
# Epoch 18/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0240 - mae: 0.1158 - val_loss: 0.0166 - val_mae: 0.0939
# Epoch 19/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0237 - mae: 0.1155 - val_loss: 0.0211 - val_mae: 0.1104
# Epoch 20/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0217 - mae: 0.1103 - val_loss: 0.0222 - val_mae: 0.1171
# Epoch 21/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0219 - mae: 0.1104 - val_loss: 0.0162 - val_mae: 0.0953
# Epoch 22/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1052 - val_loss: 0.0162 - val_mae: 0.0944
# Epoch 23/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.1044 - val_loss: 0.0179 - val_mae: 0.1011
# Epoch 24/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0200 - mae: 0.1057 - val_loss: 0.0163 - val_mae: 0.0936
# Epoch 25/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - mae: 0.1038 - val_loss: 0.0162 - val_mae: 0.0951
# Epoch 26/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - mae: 0.0999 - val_loss: 0.0148 - val_mae: 0.0883
# Epoch 27/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - mae: 0.0993 - val_loss: 0.0141 - val_mae: 0.0853
# Epoch 28/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173 - mae: 0.0963 - val_loss: 0.0162 - val_mae: 0.0949
# Epoch 29/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - mae: 0.0971 - val_loss: 0.0161 - val_mae: 0.0932
# Epoch 30/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - mae: 0.0958 - val_loss: 0.0143 - val_mae: 0.0867
# Epoch 31/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0157 - mae: 0.0923 - val_loss: 0.0140 - val_mae: 0.0852
# Epoch 32/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0157 - mae: 0.0920 - val_loss: 0.0144 - val_mae: 0.0872
# Epoch 33/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152 - mae: 0.0899 - val_loss: 0.0134 - val_mae: 0.0812
# Epoch 34/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150 - mae: 0.0885 - val_loss: 0.0137 - val_mae: 0.0837
# Epoch 35/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0138 - mae: 0.0862 - val_loss: 0.0148 - val_mae: 0.0900
# Epoch 36/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0140 - mae: 0.0854 - val_loss: 0.0129 - val_mae: 0.0808
# Epoch 37/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133 - mae: 0.0849 - val_loss: 0.0128 - val_mae: 0.0781
# Epoch 38/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0127 - mae: 0.0829 - val_loss: 0.0134 - val_mae: 0.0833
# Epoch 39/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - mae: 0.0827 - val_loss: 0.0126 - val_mae: 0.0784
# Epoch 40/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124 - mae: 0.0821 - val_loss: 0.0125 - val_mae: 0.0779
# Epoch 41/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0126 - mae: 0.0816 - val_loss: 0.0131 - val_mae: 0.0801
# Epoch 42/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0119 - mae: 0.0791 - val_loss: 0.0122 - val_mae: 0.0770
# Epoch 43/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0116 - mae: 0.0787 - val_loss: 0.0121 - val_mae: 0.0765
# Epoch 44/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - mae: 0.0788 - val_loss: 0.0119 - val_mae: 0.0769
# Epoch 45/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120 - mae: 0.0789 - val_loss: 0.0117 - val_mae: 0.0748
# Epoch 46/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111 - mae: 0.0765 - val_loss: 0.0106 - val_mae: 0.0715
# Epoch 47/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0113 - mae: 0.0764 - val_loss: 0.0128 - val_mae: 0.0810
# Epoch 48/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - mae: 0.0737 - val_loss: 0.0111 - val_mae: 0.0740
# Epoch 49/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0105 - mae: 0.0739 - val_loss: 0.0109 - val_mae: 0.0728
# Epoch 50/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - mae: 0.0737 - val_loss: 0.0110 - val_mae: 0.0735
# Epoch 51/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0102 - mae: 0.0729 - val_loss: 0.0122 - val_mae: 0.0774
# Epoch 52/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0722 - val_loss: 0.0109 - val_mae: 0.0715
# Epoch 53/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0094 - mae: 0.0713 - val_loss: 0.0119 - val_mae: 0.0764
# Epoch 54/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0097 - mae: 0.0714 - val_loss: 0.0107 - val_mae: 0.0721
# Epoch 55/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0095 - mae: 0.0714 - val_loss: 0.0116 - val_mae: 0.0771
# Epoch 56/1500
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0091 - mae: 0.0690 - val_loss: 0.0107 - val_mae: 0.0723
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Training complete.
# Model saved as 'dcnn_mlp_baseline_model.h5'

# %% [markdown]
# 6단계 mc Dropout

# %%
import h5py
import numpy as np
import json
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from tqdm import tqdm

# --- 1. 데이터 로드 함수 (동일) ---
def load_data_from_hdf5(h5_path):
    X1_list = [] # 이미지 (80, 80)
    X2_list = [] # 벡터 (9,)
    y_list = []  # 레이블 (RULP)

    with h5py.File(h5_path, 'r') as hf:
        bearing_names = list(hf.keys())
        for bearing_name in bearing_names:
            X1_list.append(hf[bearing_name]['X1_images'][:])
            X2_list.append(hf[bearing_name]['X2_vectors_norm'][:])
            y_list.append(hf[bearing_name]['y_labels'][:])
    
    X1_all = np.concatenate(X1_list, axis=0)
    X2_all = np.concatenate(X2_list, axis=0)
    y_all = np.concatenate(y_list, axis=0)
    
    # 채널 차원 추가
    X1_all = np.expand_dims(X1_all, axis=-1)
    
    return X1_all, X2_all, y_all

# --- 2. MC Dropout 예측 함수 (수정됨) ---
def get_mc_predictions(model, inputs_list, T=50):
    """
    모델의 Dropout을 활성화(training=True)하여
    T번 반복 예측을 수행합니다.
    """
    all_preds = []
    print(f"Running MC Dropout with T={T} iterations...")
    
    # T번 반복 예측
    for _ in tqdm(range(T)):
        # training=True로 설정하여 Dropout을 강제로 활성화!
        preds = model(inputs_list, training=True)
        all_preds.append(preds)
    
    # (T, N_samples, 1) 형태의 텐서를 (T, N_samples)로 변경
    all_preds_stacked = tf.stack(all_preds)
    all_preds_squeezed = tf.squeeze(all_preds_stacked, axis=-1)
    
    # axis=0 (T축)에 대해 평균과 분산을 계산
    mean_preds = tf.reduce_mean(all_preds_squeezed, axis=0).numpy()
    
    # [수정된 부분] tf.reduce_var -> tf.math.reduce_variance
    variance_preds = tf.math.reduce_variance(all_preds_squeezed, axis=0).numpy()
    
    return mean_preds, variance_preds

# --- 3. 메인 실행 (동일) ---
def main():
    # 3-1. 경로 및 파일 설정
    HDF5_FILE = Path("PRONOSTIA_normalized.h5")
    MODEL_FILE = Path("dcnn_mlp_baseline_model.h5")
    T_ITERATIONS = 50 # 몬테카를로 반복 횟수

    # 3-2. 모델 로드
    print(f"Loading baseline model from: {MODEL_FILE.resolve()}")
    if not MODEL_FILE.exists():
        print("Error: Model file not found. Please run Step 5 first.")
        return
    model = load_model(MODEL_FILE)

    # 3-3. 데이터 로드 및 분리 (5단계와 동일하게)
    print(f"Loading data from: {HDF5_FILE.resolve()}")
    X1_data, X2_data, y_data = load_data_from_hdf5(HDF5_FILE)
    
    # 5단계와 동일한 검증셋을 얻기 위해 random_state=42 유지
    _, X1_val, _, X2_val, _, y_val = train_test_split(
        X1_data, X2_data, y_data, 
        test_size=0.2, 
        random_state=42
    )
    print(f"Using {len(y_val)} samples from validation set for demonstration.")

    # 3-4. MC Dropout 실행
    # 전체 검증 데이터셋에 대해 한 번에 계산
    mean_predictions, variance_predictions = get_mc_predictions(
        model, 
        [X1_val, X2_val], 
        T=T_ITERATIONS
    )

    # 3-5. 결과 샘플 확인
    print("\n--- MC Dropout Prediction Results (Sample 0) ---")
    sample_idx = 0
    
    print(f"True RULP:              {y_val[sample_idx]:.6f}")
    print(f"Predicted RULP (Mean):  {mean_predictions[sample_idx]:.6f}")
    print(f"Uncertainty (Variance): {variance_predictions[sample_idx]:.6f}")
    
    print("\n--- MC Dropout Prediction Results (Sample 10) ---")
    sample_idx = 10
    
    print(f"True RULP:              {y_val[sample_idx]:.6f}")
    print(f"Predicted RULP (Mean):  {mean_predictions[sample_idx]:.6f}")
    print(f"Uncertainty (Variance): {variance_predictions[sample_idx]:.6f}")
    
    # 3-6. Active Learning을 위한 데이터 준비
    # Active Learning 시나리오에서는 이 '분산' 값을 기준으로 데이터를 정렬합니다.
    # 분산이 가장 큰 샘플의 인덱스를 찾기
    highest_uncertainty_idx = np.argmax(variance_predictions)
    
    print("\n--- Active Learning Query ---")
    print(f"Sample with highest uncertainty (Index): {highest_uncertainty_idx}")
    print(f"  > True RULP:              {y_val[highest_uncertainty_idx]:.6f}")
    print(f"  > Predicted RULP (Mean):  {mean_predictions[highest_uncertainty_idx]:.6f}")
    print(f"  > Uncertainty (Variance): {variance_predictions[highest_uncertainty_idx]:.6f} (Max)")

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Loading baseline model from: /home/work/RUL_AL/Pronostia dataset/dcnn_mlp_baseline_model.h5
# Loading data from: /home/work/RUL_AL/Pronostia dataset/PRONOSTIA_normalized.h5
# Using 620 samples from validation set for demonstration.
# Running MC Dropout with T=50 iterations...
# 100% 50/50 [00:01<00:00, 43.91it/s]
# --- MC Dropout Prediction Results (Sample 0) ---
# True RULP:              0.517473
# Predicted RULP (Mean):  0.406294
# Uncertainty (Variance): 0.003002
#
# --- MC Dropout Prediction Results (Sample 10) ---
# True RULP:              0.931452
# Predicted RULP (Mean):  0.924740
# Uncertainty (Variance): 0.000378
#
# --- Active Learning Query ---
# Sample with highest uncertainty (Index): 471
#   > True RULP:              0.000000
#   > Predicted RULP (Mean):  0.214359
#   > Uncertainty (Variance): 0.018519 (Max)
